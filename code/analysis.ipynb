# %%
# Nodige bibliotheken importeren
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Laad de dataset
data_text = pd.read_csv("/Users/rens/Github/Y2BA-Retake--Rens---Stijn-/Data/df_text_2023-10-31.csv", encoding="utf-8")

# Verken de dataset
print(data_text.info())  # Bekijk de structuur van de data
print(data_text.columns)  # Print de kolomnamen
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Columns: 419 entries, StartDate to msc_ai_t
# dtypes: object(419)
# memory usage: 2.0+ MB
# None
# Index(['StartDate', 'EndDate', 'Status', 'Progress', 'Duration (in seconds)',
#        'Finished', 'RecordedDate', 'ResponseId', 'DistributionChannel',
#        'UserLanguage',
#        ...
#        'Q9.9', 'Q10.2', 'Q10.3', 'Q10.4', 'Q10.5', 'Q10.6', 'Q10.7', '10.8',
#        'Q10.9', 'msc_ai_t'],
#       dtype='object', length=419)

# %%
# Bekijk de eerste 10 rijen
print(data_text.head(10))

# Bekijk een willekeurige steekproef van rijen
print(data_text.sample(10))
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/De...
# 2                                2023-10-05 00:22:01
# 3                                2023-10-05 01:23:44
# 4                                2023-10-05 01:47:28
# 5                                2023-10-05 02:26:10
# 6                                2023-10-05 02:35:21
# 7                                2023-10-05 03:16:26
# 8                                2023-10-05 04:36:45
# 9                                2023-10-05 06:00:58
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Denv...  {"ImportId":"status"}
# 2                                2023-10-05 00:48:42             IP Address
# ...
